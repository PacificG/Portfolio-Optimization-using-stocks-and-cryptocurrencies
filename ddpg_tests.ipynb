# %%
#!/usr/bin/env python
# coding: utf-8

# Deep Deterministic Policy Gradient for Portfolio Management
#  
# 1. We have already overfit the model by training on 16 stocks using 3 years of training data 
# Training was done by running stock_traindg.py using DDPG lstm 3 steps window on these 16 stocks
# ['AAPL', 'ATVI', 'CMCSA', 'COST', 'CSX', 'DISH', 'EA', 'EBAY', 'FB', 'GOOGL', 'HAS', 'ILMN', 'INTC', 'MAR', 'REGN', 'SBUX']
#
# 2. We then load a second dataset with different 16 stocks OHLC data
# 3. We test the model performance on the new stocks data (not seen during training) for the training time period
# 4. We then test the model performance on the new stocks data for the testing time period (neither was seen during training)

# %%
import os
#os.chdir('/mnt/c/c/Users/byacoube/source/repos/capstone/src')
#os.chdir(r'C:\Users\byacoube\source\repos\capstone\src')
#from google.colab import drive
#drive.mount('/content/drive')
os.environ["KERAS_BACKEND"] = "theano"
import numpy as np
from utils.data import read_stock_history, index_to_date, date_to_index, normalize
import matplotlib.pyplot as plt
import matplotlib
# for compatible with python 3
#from __future__ import print_function
get_ipython().run_line_magic('matplotlib', 'inline')
get_ipython().run_line_magic('load_ext', 'autoreload')
get_ipython().run_line_magic('autoreload', '2')

# %%
# Seaborn, useful for graphics
import seaborn as sns

# Import Bokeh modules for interactive plotting
import bokeh.io
#import bokeh.mpl
import bokeh.plotting

# Magic function to make matplotlib inline; other style specs must come AFTER
get_ipython().run_line_magic('matplotlib', 'inline')

# This enables SVG graphics inline.  There is a bug, so uncomment if it works.
# %config InlineBackend.figure_formats = {'svg',}

# This enables high resolution PNGs. SVG is preferred, but has problems
# rendering vertical and horizontal lines
get_ipython().run_line_magic('config', "InlineBackend.figure_formats = {'png', 'retina'}")
matplotlib.rcParams['figure.figsize'] = (10, 6)
plt.rc('legend', fontsize=20)
# configure Seaborn settings 
rc = {'lines.linewidth': 2, 
      'axes.labelsize': 18, 
      'axes.titlesize': 18, 
      'axes.facecolor': 'EFEFD5'}
sns.set_context('notebook', rc=rc)
sns.set_style('darkgrid', rc=rc)

# Set up Bokeh for inline viewing
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# read the data and choose the target stocks for training a toy example
history, abbreviation = read_stock_history(filepath='utils/datasets/stocks_history_target.h5')
history = history[:, :, :4]
num_training_time = history.shape[1]
num_testing_time = history.shape[1]
window_length = 3

# %%
# dataset for 16 stocks by splitting timestamp
history, abbreviation = read_stock_history(filepath='utils/datasets/stocks_history_target.h5')
history = history[:, :, :4]

# 16 stocks are all involved. We choose first 3 years as training data
num_training_time = 1095
target_stocks = abbreviation
target_history = np.empty(shape=(len(target_stocks), num_training_time, history.shape[2]))

for i, stock in enumerate(target_stocks):
    target_history[i] = history[abbreviation.index(stock), :num_training_time, :]

# and last 2 years as testing data.
testing_stocks = abbreviation
testing_history = np.empty(shape=(len(testing_stocks), history.shape[1] - num_training_time, 
                               history.shape[2]))
for i, stock in enumerate(testing_stocks):
    testing_history[i] = history[abbreviation.index(stock), num_training_time:, :]
print( abbreviation)
print("target_history.shape stocks, steps, OHLC", target_history.shape)
print("testing_history.shape stocks, steps, OHLC", testing_history.shape)
# Out:
# ['AAPL', 'ATVI', 'CMCSA', 'COST', 'CSX', 'DISH', 'EA', 'EBAY', 'FB', 'GOOGL', 'HAS', 'ILMN', 'INTC', 'MAR', 'REGN', 'SBUX']
# target_history.shape stocks, steps, OHLC (16, 1095, 4)
# testing_history.shape stocks, steps, OHLC (16, 730, 4)

# %%
nb_classes = len(target_stocks) + 1

# visualize stock prices
if True:
    date_list = [index_to_date(i) for i in range(target_history.shape[1])]
    x = range(target_history.shape[1])
    for i in range(len(target_stocks)):
        plt.figure(i)
        plt.plot(x, target_history[i, :, 1])  # open, high, low, close = [0, 1, 2, 3]
        plt.xticks(x[::200], date_list[::200], rotation=30)
        plt.title(target_stocks[i])
        plt.show()

# %%
import tensorflow as tf
from model.ddpg.actor import ActorNetwork
from model.ddpg.critic import CriticNetwork
from model.ddpg.ddpg import DDPG
from model.ddpg.ornstein_uhlenbeck import OrnsteinUhlenbeckActionNoise

import numpy as np
import tflearn

from stock_trading import StockActor, StockCritic, obs_normalizer, get_model_path, get_result_path,test_model, get_variable_scope, test_model_multiple
    
from model.supervised.lstm import StockLSTM
from model.supervised.cnn import StockCNN
tf.__version__
# Out:
# '1.15.0'

# %%
# common settings
batch_size = 64
action_bound = 1.
tau = 1e-3

models = []
model_names = []
window_length_lst = [3]
predictor_type_lst = ['lstm']
use_batch_norm = True


# instantiate environment, 16 stocks, with trading cost, window_length 3, start_date sample each time
for window_length in window_length_lst:
    for predictor_type in predictor_type_lst:
        name = 'DDPG_window_{}_predictor_{}'.format(window_length, predictor_type)
        model_names.append(name)
        tf.reset_default_graph()
        sess = tf.Session()
        tflearn.config.init_training_mode()
        action_dim = [nb_classes]
        state_dim = [nb_classes, window_length]
        variable_scope = get_variable_scope(window_length, predictor_type, use_batch_norm)
        with tf.variable_scope(variable_scope):
            actor = StockActor(sess, state_dim, action_dim, action_bound, 1e-4, tau, batch_size, predictor_type, 
                               use_batch_norm)
            critic = StockCritic(sess=sess, state_dim=state_dim, action_dim=action_dim, tau=1e-3,
                                 learning_rate=1e-3, num_actor_vars=actor.get_num_trainable_vars(), 
                                 predictor_type=predictor_type, use_batch_norm=use_batch_norm)
            actor_noise = OrnsteinUhlenbeckActionNoise(mu=np.zeros(action_dim))

            model_save_path = get_model_path(window_length, predictor_type, use_batch_norm)
            summary_path = get_result_path(window_length, predictor_type, use_batch_norm)

            ddpg_model = DDPG(None, sess, actor, critic, actor_noise, obs_normalizer=obs_normalizer,
                              config_file='config/stock.json', model_save_path=model_save_path,
                              summary_path=summary_path)
            ddpg_model.initialize(load_weights=True, verbose=True)
            models.append(ddpg_model)
# Out:
# WARNING:tensorflow:From C:\Users\byacoube\AppData\Local\Continuum\anaconda3\lib\site-packages\tflearn\layers\core.py:81: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\byacoube\AppData\Local\Continuum\anaconda3\lib\site-packages\tflearn\layers\recurrent.py:69: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\byacoube\AppData\Local\Continuum\anaconda3\lib\site-packages\tflearn\layers\recurrent.py:553: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\byacoube\AppData\Local\Continuum\anaconda3\lib\site-packages\tflearn\initializations.py:174: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\byacoube\AppData\Local\Continuum\anaconda3\lib\site-packages\tflearn\initializations.py:75: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From E:\Google Drive\capstone\deliverables\X. code\src\model\ddpg\actor.py:47: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From E:\Google Drive\capstone\deliverables\X. code\src\model\ddpg\actor.py:68: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From E:\Google Drive\capstone\deliverables\X. code\src\model\ddpg\actor.py:71: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From E:\Google Drive\capstone\deliverables\X. code\src\model\ddpg\ddpg.py:18: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From E:\Google Drive\capstone\deliverables\X. code\src\model\ddpg\ddpg.py:23: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From E:\Google Drive\capstone\deliverables\X. code\src\model\ddpg\ddpg.py:56: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From E:\Google Drive\capstone\deliverables\X. code\src\model\ddpg\ddpg.py:58: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# INFO:tensorflow:Restoring parameters from weights/stock/lstm/window_3/batch_norm/checkpoint.ckpt
# Loading is_training:0 from checkpoint. Name: is_training
# Loading lstm_window_3_batch_norm/LSTM/lstm_window_3_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: lstm_window_3_batch_norm/LSTM/lstm_window_3_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix
# Loading lstm_window_3_batch_norm/LSTM/lstm_window_3_batch_norm/LSTM/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: lstm_window_3_batch_norm/LSTM/lstm_window_3_batch_norm/LSTM/BasicLSTMCell/Linear/Bias
# Loading lstm_window_3_batch_norm/FullyConnected/W:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected/W
# Loading lstm_window_3_batch_norm/FullyConnected/b:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected/b
# Loading lstm_window_3_batch_norm/BatchNormalization/beta:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization/beta
# Loading lstm_window_3_batch_norm/BatchNormalization/gamma:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization/gamma
# Loading lstm_window_3_batch_norm/BatchNormalization/moving_mean:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization/moving_mean
# Loading lstm_window_3_batch_norm/BatchNormalization/moving_variance:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization/moving_variance
# Loading lstm_window_3_batch_norm/FullyConnected_1/W:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_1/W
# Loading lstm_window_3_batch_norm/FullyConnected_1/b:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_1/b
# Loading lstm_window_3_batch_norm/BatchNormalization_1/beta:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_1/beta
# Loading lstm_window_3_batch_norm/BatchNormalization_1/gamma:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_1/gamma
# Loading lstm_window_3_batch_norm/BatchNormalization_1/moving_mean:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_1/moving_mean
# Loading lstm_window_3_batch_norm/BatchNormalization_1/moving_variance:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_1/moving_variance
# Loading lstm_window_3_batch_norm/FullyConnected_2/W:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_2/W
# Loading lstm_window_3_batch_norm/FullyConnected_2/b:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_2/b
# Loading lstm_window_3_batch_norm/LSTM_1/lstm_window_3_batch_norm/LSTM_1/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: lstm_window_3_batch_norm/LSTM_1/lstm_window_3_batch_norm/LSTM_1/BasicLSTMCell/Linear/Matrix
# Loading lstm_window_3_batch_norm/LSTM_1/lstm_window_3_batch_norm/LSTM_1/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: lstm_window_3_batch_norm/LSTM_1/lstm_window_3_batch_norm/LSTM_1/BasicLSTMCell/Linear/Bias
# Loading lstm_window_3_batch_norm/FullyConnected_3/W:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_3/W
# Loading lstm_window_3_batch_norm/FullyConnected_3/b:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_3/b
# Loading lstm_window_3_batch_norm/BatchNormalization_2/beta:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_2/beta
# Loading lstm_window_3_batch_norm/BatchNormalization_2/gamma:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_2/gamma
# Loading lstm_window_3_batch_norm/BatchNormalization_2/moving_mean:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_2/moving_mean
# Loading lstm_window_3_batch_norm/BatchNormalization_2/moving_variance:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_2/moving_variance
# Loading lstm_window_3_batch_norm/FullyConnected_4/W:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_4/W
# Loading lstm_window_3_batch_norm/FullyConnected_4/b:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_4/b
# Loading lstm_window_3_batch_norm/BatchNormalization_3/beta:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_3/beta
# Loading lstm_window_3_batch_norm/BatchNormalization_3/gamma:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_3/gamma
# Loading lstm_window_3_batch_norm/BatchNormalization_3/moving_mean:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_3/moving_mean
# Loading lstm_window_3_batch_norm/BatchNormalization_3/moving_variance:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_3/moving_variance
# Loading lstm_window_3_batch_norm/FullyConnected_5/W:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_5/W
# Loading lstm_window_3_batch_norm/FullyConnected_5/b:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_5/b
# Loading lstm_window_3_batch_norm/beta1_power:0 from checkpoint. Name: lstm_window_3_batch_norm/beta1_power
# Loading lstm_window_3_batch_norm/beta2_power:0 from checkpoint. Name: lstm_window_3_batch_norm/beta2_power
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM/lstm_window_3_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM/lstm_window_3_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM/lstm_window_3_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM/lstm_window_3_batch_norm/LSTM/BasicLSTMCell/Linear/Matrix/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM/lstm_window_3_batch_norm/LSTM/BasicLSTMCell/Linear/Bias/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM/lstm_window_3_batch_norm/LSTM/BasicLSTMCell/Linear/Bias/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM/lstm_window_3_batch_norm/LSTM/BasicLSTMCell/Linear/Bias/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM/lstm_window_3_batch_norm/LSTM/BasicLSTMCell/Linear/Bias/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected/W/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected/W/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected/W/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected/W/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected/b/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected/b/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected/b/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected/b/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization/beta/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization/beta/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization/beta/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization/beta/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization/gamma/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization/gamma/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization/gamma/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization/gamma/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_1/W/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_1/W/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_1/W/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_1/W/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_1/b/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_1/b/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_1/b/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_1/b/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_1/beta/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_1/beta/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_1/beta/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_1/beta/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_1/gamma/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_1/gamma/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_1/gamma/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_1/gamma/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_2/W/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_2/W/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_2/W/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_2/W/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_2/b/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_2/b/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_2/b/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_2/b/Adam_1
# Loading lstm_window_3_batch_norm/LSTM_2/lstm_window_3_batch_norm/LSTM_2/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: lstm_window_3_batch_norm/LSTM_2/lstm_window_3_batch_norm/LSTM_2/BasicLSTMCell/Linear/Matrix
# Loading lstm_window_3_batch_norm/LSTM_2/lstm_window_3_batch_norm/LSTM_2/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: lstm_window_3_batch_norm/LSTM_2/lstm_window_3_batch_norm/LSTM_2/BasicLSTMCell/Linear/Bias
# Loading lstm_window_3_batch_norm/FullyConnected_6/W:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_6/W
# Loading lstm_window_3_batch_norm/FullyConnected_6/b:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_6/b
# Loading lstm_window_3_batch_norm/FullyConnected_7/W:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_7/W
# Loading lstm_window_3_batch_norm/FullyConnected_7/b:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_7/b
# Loading lstm_window_3_batch_norm/BatchNormalization_4/beta:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_4/beta
# Loading lstm_window_3_batch_norm/BatchNormalization_4/gamma:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_4/gamma
# Loading lstm_window_3_batch_norm/BatchNormalization_4/moving_mean:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_4/moving_mean
# Loading lstm_window_3_batch_norm/BatchNormalization_4/moving_variance:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_4/moving_variance
# Loading lstm_window_3_batch_norm/FullyConnected_8/W:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_8/W
# Loading lstm_window_3_batch_norm/FullyConnected_8/b:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_8/b
# Loading lstm_window_3_batch_norm/LSTM_3/lstm_window_3_batch_norm/LSTM_3/BasicLSTMCell/Linear/Matrix:0 from checkpoint. Name: lstm_window_3_batch_norm/LSTM_3/lstm_window_3_batch_norm/LSTM_3/BasicLSTMCell/Linear/Matrix
# Loading lstm_window_3_batch_norm/LSTM_3/lstm_window_3_batch_norm/LSTM_3/BasicLSTMCell/Linear/Bias:0 from checkpoint. Name: lstm_window_3_batch_norm/LSTM_3/lstm_window_3_batch_norm/LSTM_3/BasicLSTMCell/Linear/Bias
# Loading lstm_window_3_batch_norm/FullyConnected_9/W:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_9/W
# Loading lstm_window_3_batch_norm/FullyConnected_9/b:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_9/b
# Loading lstm_window_3_batch_norm/FullyConnected_10/W:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_10/W
# Loading lstm_window_3_batch_norm/FullyConnected_10/b:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_10/b
# Loading lstm_window_3_batch_norm/BatchNormalization_5/beta:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_5/beta
# Loading lstm_window_3_batch_norm/BatchNormalization_5/gamma:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_5/gamma
# Loading lstm_window_3_batch_norm/BatchNormalization_5/moving_mean:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_5/moving_mean
# Loading lstm_window_3_batch_norm/BatchNormalization_5/moving_variance:0 from checkpoint. Name: lstm_window_3_batch_norm/BatchNormalization_5/moving_variance
# Loading lstm_window_3_batch_norm/FullyConnected_11/W:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_11/W
# Loading lstm_window_3_batch_norm/FullyConnected_11/b:0 from checkpoint. Name: lstm_window_3_batch_norm/FullyConnected_11/b
# Loading lstm_window_3_batch_norm/beta1_power_1:0 from checkpoint. Name: lstm_window_3_batch_norm/beta1_power_1
# Loading lstm_window_3_batch_norm/beta2_power_1:0 from checkpoint. Name: lstm_window_3_batch_norm/beta2_power_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM_2/lstm_window_3_batch_norm/LSTM_2/BasicLSTMCell/Linear/Matrix/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM_2/lstm_window_3_batch_norm/LSTM_2/BasicLSTMCell/Linear/Matrix/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM_2/lstm_window_3_batch_norm/LSTM_2/BasicLSTMCell/Linear/Matrix/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM_2/lstm_window_3_batch_norm/LSTM_2/BasicLSTMCell/Linear/Matrix/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM_2/lstm_window_3_batch_norm/LSTM_2/BasicLSTMCell/Linear/Bias/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM_2/lstm_window_3_batch_norm/LSTM_2/BasicLSTMCell/Linear/Bias/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM_2/lstm_window_3_batch_norm/LSTM_2/BasicLSTMCell/Linear/Bias/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/LSTM_2/lstm_window_3_batch_norm/LSTM_2/BasicLSTMCell/Linear/Bias/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_6/W/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_6/W/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_6/W/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_6/W/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_6/b/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_6/b/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_6/b/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_6/b/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_7/W/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_7/W/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_7/W/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_7/W/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_7/b/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_7/b/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_7/b/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_7/b/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_4/beta/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_4/beta/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_4/beta/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_4/beta/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_4/gamma/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_4/gamma/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_4/gamma/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/BatchNormalization_4/gamma/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_8/W/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_8/W/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_8/W/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_8/W/Adam_1
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_8/b/Adam:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_8/b/Adam
# Loading lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_8/b/Adam_1:0 from checkpoint. Name: lstm_window_3_batch_norm/lstm_window_3_batch_norm/FullyConnected_8/b/Adam_1
# Loading lstm_window_3_batch_norm/Variable:0 from checkpoint. Name: lstm_window_3_batch_norm/Variable
# Loading lstm_window_3_batch_norm/Variable_1:0 from checkpoint. Name: lstm_window_3_batch_norm/Variable_1

# %%
# create a second dataset for testing that contains different stocks from training stocks shown above
history, abbreviation = read_stock_history(filepath='utils/datasets/stocks_history_target_2.h5')
history = history[:, :, :4]
nb_classes = len(history) + 1
print(history.shape)
print('second stock dataset', abbreviation)
testing_history = history
testing_stocks = abbreviation
target_history = history
target_stocks = abbreviation
# Out:
# (16, 1825, 4)
# second stock dataset ['FOX', 'FISV', 'EXPE', 'FAST', 'ESRX', 'DLTR', 'CTSH', 'CSCO', 'QCOM', 'PCLN', 'CELG', 'AMGN', 'WFM', 'WDC', 'NVDA', 'STX']

# %%
from environment.portfolio import PortfolioEnv, MultiActionPortfolioEnv

# %%
# evaluate the model with dates seen in training but from the second different stocks dataset
env = MultiActionPortfolioEnv(target_history, target_stocks, model_names[:1], steps=1500, 
                              sample_start_date='2012-10-30')

observations_list, info_list, actions_list, df_performance = test_model_multiple(env, models[:1])

# %%
# evaluate the model with unseen dates from the second different stocks dataset, fixed the starting date
env = MultiActionPortfolioEnv(testing_history, testing_stocks, model_names[:1], steps=650, 
                              start_idx=num_training_time, sample_start_date='2016-12-8')

observations_list, info_list, actions_list, df_performance = test_model_multiple(env, models[:1])

# %%
import pandas as pd
actions_list = np.array(actions_list).squeeze(1)
abbreviation.insert(0,'blank')
df_actions = pd.DataFrame(actions_list, columns=abbreviation)
print('stock symbols: ', abbreviation)#[ np.argmax(actions_list[0]) -1])
maxValueIndexObj = df_actions.idxmax(axis=1)
print(' ')
print("Stock selected by the agent for each step :")
print(maxValueIndexObj)
# Out:
# stock symbols:  ['blank', 'FOX', 'FISV', 'EXPE', 'FAST', 'ESRX', 'DLTR', 'CTSH', 'CSCO', 'QCOM', 'PCLN', 'CELG', 'AMGN', 'WFM', 'WDC', 'NVDA', 'STX']
#
# Stock selected by the agent for each step :
# 0      CTSH
# 1      CTSH
# 2      CTSH
# 3      PCLN
# 4       FOX
#        ...
# 646    PCLN
# 647    CTSH
# 648    PCLN
# 649    PCLN
# 650    FISV
# Length: 651, dtype: object

# %%
df_performance = df_performance.reset_index()
maxValueIndexObj.name="stocks"
result = pd.concat([ maxValueIndexObj, df_performance.reindex(maxValueIndexObj.index)], axis=1)

print(result)
# Out:
#     stocks       date  DDPG_window_3_predictor_lstm  market_value
# 0     CTSH 2016-12-09                      0.984015      0.993631
# 1     CTSH 2016-12-10                      0.987143      0.999179
# 2     CTSH 2016-12-11                      0.969923      0.988202
# 3     PCLN 2016-12-12                      0.966010      0.985856
# 4      FOX 2016-12-13                      0.979133      0.979342
# ..     ...        ...                           ...           ...
# 646   PCLN 2018-09-16                      2.102439      0.877026
# 647   CTSH 2018-09-17                      2.083227      0.876713
# 648   PCLN 2018-09-18                      2.071608      0.868662
# 649   PCLN 2018-09-19                      2.060055      0.860686
# 650   FISV 2018-09-20                      2.062582      0.852783
#
# [651 rows x 4 columns]

# %%
# histogram of the stocks selected by the agent
maxValueIndexObj.hist()
maxValueIndexObj.unique()
# Out:
# array(['CTSH', 'PCLN', 'FOX', 'FISV'], dtype=object)

# %%
# show the stocks selected by the agent at each step in the test period
import matplotlib.pyplot as plt
ax = plt.gca()

df_fox = result.loc[result['stocks'] == 'FOX']
df_ctsh = result.loc[result['stocks'] == 'CTSH']
df_pcln = result.loc[result['stocks'] == 'PCLN']
df_fisv = result.loc[result['stocks'] == 'FISV']
df_fox.index.name = 'idx'
df_ctsh.index.name = 'idx'
df_pcln.index.name = 'idx'
df_fisv.index.name = 'idx'


df= df_fox.reset_index()
df.plot(kind='scatter',x='idx',y='DDPG_window_3_predictor_lstm', color='blue', ax=ax, s=3, label='FOX')
df= df_fisv.reset_index()
df.plot(kind='scatter',x='idx', y='DDPG_window_3_predictor_lstm', color='red', ax=ax, s=3,label='FISV')
df= df_pcln.reset_index()
df.plot(kind='scatter',x='idx', y='DDPG_window_3_predictor_lstm', color='brown', ax=ax, s=3,label='PCLN')
df= df_ctsh.reset_index()
df.plot(kind='scatter',x='idx', y='DDPG_window_3_predictor_lstm', color='green', ax=ax, s=3,label='CTSH')
ax.legend()

plt.show()
